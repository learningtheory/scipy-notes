# %%
import collections

# %%
collections?

# %%
c = collections.defaultdict(str)

# %%
c
# Out:
# defaultdict(str, {})

# %%
c['a']
# Out:
# ''

# %%
m = collections.defaultdict(lambda: 2)

# %%
m
# Out:
# defaultdict(<function __main__.<lambda>>, {})

# %%
m['a']
# Out:
# 2

# %%
m['aa']
# Out:
# 2

# %%
print(m)
# Out:
# defaultdict(<function <lambda> at 0x108d579d8>, {'a': 2, 'aa': 2})

# %%
import itertools
for p in itertools.product([1, 2, 3], [4, 5]):
    print(p)
# Out:
# (1, 4)
# (1, 5)
# (2, 4)
# (2, 5)
# (3, 4)
# (3, 5)

# %%
for s in itertools.combinations([1, 2, 3], 2):
    print(s)
# Out:
# (1, 2)
# (1, 3)
# (2, 3)

# %%
l = dict([['a', 1], ['b', 2]])

# %%
l
# Out:
# {'a': 1, 'b': 2}

# %%
sorted(l,key=lambda x:'23',reverse=False)
# Out:
# ['a', 'b']

# %%
l
# Out:
# {'a': 1, 'b': 2}

# %%
v = sorted(l,reverse=True)

# %%
v
# Out:
# ['b', 'a']

# %%
sorted(l, key=lambda x: l[x], reverse=True)
# Out:
# ['b', 'a']

# %%
lambda x: l[x]
# Out:
# <function __main__.<lambda>>

# %%
l
# Out:
# {'a': 1, 'b': 2}

# %%
a = lambda x:l.get(x)

# %%
type(a)
# Out:
# function

# %%
a?
